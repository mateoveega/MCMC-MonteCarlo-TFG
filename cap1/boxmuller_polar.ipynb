# %%
import os
import sys

nombre_repositorio = 'MCMC-MonteCarlo-TFG'
url_repositorio = f'https://github.com/mateoveega/{nombre_repositorio}.git'

if not os.path.exists(f'/content/{nombre_repositorio}'):
    # !git clone {url_repositorio}

if f'/content/{nombre_repositorio}' not in sys.path:
    sys.path.append(f'/content/{nombre_repositorio}')

import numpy as np
import matplotlib.pyplot as plt

from samplers import box_muller
# Out:
# Cloning into 'MCMC-MonteCarlo-TFG'...
# remote: Enumerating objects: 432, done.
# remote: Counting objects: 100% (113/113), done.
# remote: Compressing objects: 100% (107/107), done.
# remote: Total 432 (delta 60), reused 4 (delta 4), pack-reused 319 (from 2)
# Receiving objects: 100% (432/432), 7.63 MiB | 15.98 MiB/s, done.
# Resolving deltas: 100% (213/213), done.

# %%
vector_medias = np.array([2, 3])
matriz_covarianza = np.array([[1.0, 0.8], [0.8, 1.5]])
num_muestras = 1000
descomposicion_cholesky = np.linalg.cholesky(matriz_covarianza)
dimension = vector_medias.shape[0]

muestras_normales = box_muller(dimension, num_muestras)
muestras_transformadas = vector_medias[:, np.newaxis] + descomposicion_cholesky @ muestras_normales.T
muestras_finales = muestras_transformadas.T

plt.figure(figsize=(8, 6))
plt.scatter(muestras_finales[:, 0], muestras_finales[:, 1], alpha=0.6)

plt.axvline(vector_medias[0], linestyle='--', color='r')
plt.axhline(vector_medias[1], linestyle='--', color='g')
plt.axis('equal')
plt.grid(True)
plt.tick_params(axis='both', labelsize=14)
plt.savefig("NORMAL_MULTIVARIANTE_boxmuller.pdf")
plt.show()

# %%
from google.colab import files
files.download("NORMAL_MULTIVARIANTE_boxmuller.pdf")
